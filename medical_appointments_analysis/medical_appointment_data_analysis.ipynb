# %% [markdown]
# # Investigating Patient Appointment Data
# Kaggle Data Page: https://www.kaggle.com/joniarroba/noshowappointments
#
# Author: Aditya G Kamath
#
# Report Date: 12/16/2018
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# In this project, we will be investigating data that comes from more than 100,000 records of appointments at various hospitals and health clinics in Brazil. Our response variable or target feature of interest for each record is the 'No-show' which tells us if the patient who the particular appointment was for showed up at the scheduled time or not.

# %%
#let's import the necessary libraries
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %%
# let's read in the data using pandas' read_csv() function
data= pd.read_csv('noshowappointments-kagglev2-may-2016.csv')

# %%
# let's explore the first few lines of the dataset
data.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No

# %% [markdown]
# We take a quick look at the dataset above using the head() function. Looks like some columns like the 'PatientId', 'ScheduledDay' and 'AppointmentDay' need to be formatted to reflect their correct data types. Also note that in our study, the 'No-show' column will be our dependent or output variable and currently it is a Categorial variable with 'Yes' or 'No' for values. This must be converted to a binary value of '0's and '1's so that we can use it for exploratory visualization.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# We take a deeper look at the columns using the info() function. We see that none of the 14 columns have any null values. Many other columns show up as 'objects' but we need to look at it more carefully to see if we need to explicitly convert them to the most appropriate data types.

# %%
# check to see if there are any duplicated rows
data.duplicated().value_counts()
# Out:
# False    110527
# dtype: int64

# %% [markdown]
# There seem to be no duplicated rows in this dataset of 110527 rows.

# %%
data.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       4.000000
#
#         SMS_received
# count  110527.000000
# mean        0.321026
# std         0.466873
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# Using the describe() function we can see take a look at common statistics of each of the columns. Again, it is apparent from the results that the 'PatientId' and 'AppointmentID' need to be converted to integer or string values since they are just indetifiers for each row and not values. Many features like Hipertension, Alcoholism and SMS_received are binary integers as can be seen from their 'min' and 'max' values being 0's and 1's. One very interesting observation that could be an anomaly is the 'Age' feature. Notice that the 'min' age is -1. Realistically, this cannot be true. So let's explore that columns closer.

# %%
data.query('Age==-1')
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %% [markdown]
# This looks like an anomalous record, so let's drop it in the data wrangling step later on.

# %% [markdown]
# ### Data Cleaning

# %%
#change all column names to lower case so that it is easier for us to remember and reference the columns
data.columns = map(lambda x: x.lower(), list(data.columns))

# %%
#convert patientid and appointmentid to integers
data.patientid = data.patientid.astype(int)
data.appointmentid = data.appointmentid.astype(int)

# %% [markdown]
# We are explicitely converting these two columns to the integer data type becuase they are can act like 'keys' to the records in the data frame and could come in handy while we subset the data further into the analysis.

# %%
#use the drop function to drop the row by index
data.drop([99832], inplace= True)

# %%
# let's make sure that the record has been dropped
data.query('age==-1')
# Out:
# Empty DataFrame
# Columns: [patientid, appointmentid, gender, scheduledday, appointmentday, age, neighbourhood, scholarship, hipertension, diabetes, alcoholism, handcap, sms_received, no-show]
# Index: []

# %%
# create new columns with binary values as proxy columns for no-shows and gender respectively
data['no_show_binary'] = data['no-show'].apply(lambda x: 1 if x == 'Yes' else 0)
data['gender_binary'] = data['gender'].apply(lambda x: 1 if x == 'M' else 0)

# %% [markdown]
# The reason we are creating these proxy binary rows is so that we can use these values to create visualizations and calculate statistics later into our analysis.

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %%
data['no-show'].value_counts()
# Out:
# No     88207
# Yes    22319
# Name: no-show, dtype: int64

# %% [markdown]
# Just as an ineteresting observation, from the step above we see that the proportion of no-shows is approximately 4 times higher than the shows.

# %% [markdown]
# ### 1. Does being older or younger affect no-shows?

# %%
plt.xlabel('Age (Years)')
plt.ylabel('Frequency')
data.query('gender=="F"')['age'].plot('hist', label= 'Female', alpha= 0.8);
data.query('gender=="M"')['age'].plot('hist', label= 'Male', alpha= 0.8);
plt.legend()

# %%
plt.xlabel('No-Show')
plt.ylabel('Mean Age (Years)')
data.groupby('no-show')['age'].mean().plot(kind= 'bar')

# %%
data.groupby('no-show')['age'].mean()
# Out:
# no-show
# No     37.790504
# Yes    34.317667
# Name: age, dtype: float64

# %% [markdown]
# In the first plot above, we look at the age distribution of males and females. Looks like the female patients are on average older than the male patients. In the second plot, we can see that the average age of those patients who showed up is slightly higher than those patients with no-shows.

# %% [markdown]
# ### 2. Does gender affect no-shows?

# %%
# count the no-shows by the female gender
genF= data.query('gender=="F"')['no-show'].value_counts()

# %%
plt.xlabel('No-Show')
plt.ylabel('Proportion')
genF.apply(lambda x: x/genF.sum()).plot('bar');

# %%
# count the no-shows by the male gender
genM= data.query('gender=="M"')['no-show'].value_counts()

# %%
plt.xlabel('No-Show')
plt.ylabel('Proportion')
genM.apply(lambda x: x/genM.sum()).plot('bar');

# %% [markdown]
# In trying to answer this question, let's see if being male or female affects the no-show rate. We find the proportion of no-shows for both male patients and female patients and compare them. From both the plots above, we see that proportion of no-shows is almost the same for both males and females at nearly 20%.

# %% [markdown]
# ### 3. Does being an alcoholic affect patient no-shows?

# %%
# count the no-shows by patients who are alcoholics 
alc1= data.query('alcoholism=="1"')['no-show'].value_counts()

# %%
plt.xlabel('No-Show')
plt.ylabel('Proportion')
alc1.apply(lambda x: x/alc1.sum()).plot('bar');

# %%
# count the no-shows by patients who are not alcoholics 
alc0= data.query('alcoholism=="0"')['no-show'].value_counts()

# %%
plt.xlabel('No-Show')
plt.ylabel('Proportion')
alc0.apply(lambda x: x/alc0.sum()).plot('bar');

# %% [markdown]
# The two plots above do not lead us to believe that the proportion of no-shows is affected by wether a patient is an alcoholic or not. Infact the proportion of no-shows is nearly the same at 20% for both alcoholics and non-alcoholics.

# %% [markdown]
# ### 4. Does having a Welfare Scholarship affect no-shows?

# %%
# count the no-shows by patients who are part of the welfare program 
sc1= data.query('scholarship=="1"')['no-show'].value_counts()

# %%
plt.xlabel('No-Show')
plt.ylabel('Proportion')
sc1.apply(lambda x: x/sc1.sum()).plot('bar');

# %%
# count the no-shows by patients who are not part of the welfare program 
sc0= data.query('scholarship=="0"')['no-show'].value_counts()

# %%
plt.xlabel('No-Show')
plt.ylabel('Proportion')
sc0.apply(lambda x: x/sc0.sum()).plot('bar');

# %% [markdown]
# We something surprising happening here. Again we followed the same procedure as before of comparing the proportion of no-shows for patients with welfare scholarships and those without. Comparing the two plots it's clear that patients with scholarships have a 25% chance of not showing up while the patients without scholarships the chance of no-show is lower at 20%. That's a 5% difference!

# %% [markdown]
# ### 5. Does being from a specefic neighborhood affect no-shows?

# %%
# unique number of neighborhoods that the patients come from
data['neighbourhood'].nunique()
# Out:
# 81

# %% [markdown]
# There are 81 unique neighborhoods represented in this dataset. In the next steps let's visualize the appointments by these neighborhoods.

# %%
plt.figure(figsize= (20,10))
plt.xlabel('Neighborhood')
plt.ylabel('Number of Appointments')
data['neighbourhood'].value_counts().plot('bar', title= 'Appointments By Neighborhood');

# %% [markdown]
# We use the above plot to get an idea of the distribution of the numbers of appointments by all teh neighborhoods represented in this dataset. In the next steps, let's calculate the proportion of no-shows by the neighborhoods.

# %%
# calculate the counts of shows and no-shows for each neighborhood
area1= data.groupby('neighbourhood')['no-show'].value_counts()

# %%
# calculate the proportion of no-shows and shows for each neighborhood
a_proportions = area1.groupby(level= [0]).apply(lambda x: x/x.sum())

# %%
#view the results
a_proportions
# Out:
# neighbourhood        no-show
# AEROPORTO            No         0.875000
#                      Yes        0.125000
# ANDORINHAS           No         0.769673
#                      Yes        0.230327
# ANTÔNIO HONÓRIO      No         0.815498
#                      Yes        0.184502
# ARIOVALDO FAVALESSA  No         0.780142
#                      Yes        0.219858
# BARRO VERMELHO       No         0.784870
#                      Yes        0.215130
# BELA VISTA           No         0.798637
#                      Yes        0.201363
# BENTO FERREIRA       No         0.775058
#                      Yes        0.224942
# BOA VISTA            No         0.814103
#                      Yes        0.185897
# BONFIM               No         0.801659
#                      Yes        0.198341
# CARATOÍRA            No         0.769591
#                      Yes        0.230409
# CENTRO               No         0.789142
#                      Yes        0.210858
# COMDUSA              No         0.819355
#                      Yes        0.180645
# CONQUISTA            No         0.811543
#                      Yes        0.188457
# CONSOLAÇÃO           No         0.827762
#                      Yes        0.172238
# CRUZAMENTO           No         0.782546
#                      Yes        0.217454
#                                   ...
# SANTA MARTHA         No         0.841584
#                      Yes        0.158416
# SANTA TEREZA         No         0.795796
#                      Yes        0.204204
# SANTO ANDRÉ          No         0.802412
#                      Yes        0.197588
# SANTO ANTÔNIO        No         0.823744
#                      Yes        0.176256
# SANTOS DUMONT        No         0.710815
#                      Yes        0.289185
# SANTOS REIS          No         0.795247
#                      Yes        0.204753
# SEGURANÇA DO LAR     No         0.806897
#                      Yes        0.193103
# SOLON BORGES         No         0.852878
#                      Yes        0.147122
# SÃO BENEDITO         No         0.800556
#                      Yes        0.199444
# SÃO CRISTÓVÃO        No         0.802288
#                      Yes        0.197712
# SÃO JOSÉ             No         0.783510
#                      Yes        0.216490
# SÃO PEDRO            No         0.789624
#                      Yes        0.210376
# TABUAZEIRO           No         0.817050
#                      Yes        0.182950
# UNIVERSITÁRIO        No         0.789474
#                      Yes        0.210526
# VILA RUBIM           No         0.834313
#                      Yes        0.165687
# Name: no-show, Length: 160, dtype: float64

# %%
# we are only in the no-shows for each neighborhood, so drop the 'No' rows in the 'no-show' column
a_p2= pd.DataFrame(a_proportions.drop('No', level= 'no-show'))

# %%
# rename the column for the proportions and then convert the multiple index to columns in the data frame
a_p2.columns= ['no-show_prop']
a_p2.reset_index(inplace= True)

# %%
# only keep the nighborhood column and the proportion values
a_p2= a_p2[['neighbourhood', 'no-show_prop']]

#set the neighborhood back to the index in preparation for visualization
a_p2.set_index('neighbourhood', inplace= True)

#sort the proportion values in descending order
a_p2.sort_values(by= 'no-show_prop', ascending= False, inplace= True)

# %%
# create a barchart to visualize the proportion of no-shows for each neighborhood
plt.figure(figsize= (20,10));
a_p2.plot.bar(figsize= (20,10), use_index= True);
plt.xlabel('Neighborhoods');
plt.ylabel('Proportion of No-Show Appointments');

# %% [markdown]
# It is clear from the above plot that the probability of no-shows varies by the neighborhood in which the patient lives in.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# Throughout the course of this exploratory analysis into the medical appointment no-show data set, we tried to understand which are some of those variables that affect our target feature- no-shows. Before we summarize the reesults of the questions we asked, let's talk about the assumptions we are making. We assume that:
#
# 1. The dataset is representative of the entire population of patients making appointments.
# 2. The proportion of no-shows and shows will remain consistent with future appointments. This way we know that whaterver relationship we model will be reliable in predicting future no-shows based on the features that we have in the dataset.
# 3. The questions we've explored here are not exhaustive, there are several more questions that can be explored to study the relationship between the target feature and the labels.
# 4. We have used no statistical techniques to prove that the results of our exploratory data analysis are statistically valid or that these are causal relationships. That is beyond the scope of this analysis.
#
# Now that we've stated our assumptions, let's talk summarize the results of the 5 questions we asked about the data set.
#
# 1. Does Age Affect No-Shows?
#     We found that no-show appointments tend to have patients who are on average 3 years younger than those patients who do show up for their appointments.
#
# 2. Does Gender Affect No-Shows?
#     Our analysis doesn't suggest that gender has any significant effect on the no-shows since the proportion of no-shows remains constant at 20% for both Males and Females.
#
# 3. Does Alcoholism Affect No-Shows?
#     Here as well, the proportion of No-Shows remains constant at 20% for both alcoholic and non-alocholic patients suggesting that this feature doesn't adversely affect the no-shows.
#
# 4. Does Having A Welfare Scholarship Affect No-Shows?
#     From our analysis, we found that those patients who are part of the welfare program are 5% more likely to not show up for their appointments.
#
# 5. Does The Patient's Neighborhood Affect No-Shows?
#     It is very apparent from our analysis that some neighborhoods have a very high proportion of patients who didn't show up for their appointments, while some other neighborhoods have a lower proportion of no-shows. This could be a very interesting label to test while model-building.
#
# Hopefully this analysis has given us enough evidence to begin the next step of our analysis- model-building. From the data we have, it looks like we could most likely build a regression model to test the strength of the relationship between the target feature and the labels. And going by the binary nature of the target variable, a logistic regression model will be most beneficical in prediciting future patient no-shows.

# %% [markdown]
# ### References
#
# 1. Python map function: https://stackoverflow.com/questions/41170762/python-vs-r-apply-a-function-to-each-element-in-a-vector/41170833
#
# 2. Drop rows from multi-index data frame: https://stackoverflow.com/questions/39238639/drop-specific-rows-from-multiindex-dataframe
#
# 3. Plotting a pandas data frame: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html
